# %%
import pandas as pd

# Load the CSV file into a pandas DataFrame
file_path = './.data/summary.csv'
df = pd.read_csv(file_path, on_bad_lines='skip')

# And how many rows it has
print(f"Number of rows: {len(df)}")

# Display the first few rows of the DataFrame
df.head()
# Out:
# Number of rows: 199
#       runtime  instance  async                             image  \
# 0  1743020014       1.0    1.0  wikibase/wikibase:1.39.1-wmde.11
# 1  1743021207       2.0    5.0  wikibase/wikibase:1.39.1-wmde.11
# 2  1743021474       2.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 3  1743021639       2.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 4  1743021790       2.0   60.0  wikibase/wikibase:1.39.1-wmde.11
#
#             sql  setting                       load  entity_count  \
# 0  mariadb:10.9  default  wbeditentity-FullishItems        2000.0
# 1  mariadb:10.9  default  wbeditentity-FullishItems        2000.0
# 2  mariadb:10.9  default  wbeditentity-FullishItems        2000.0
# 3  mariadb:10.9  default  wbeditentity-FullishItems        2000.0
# 4  mariadb:10.9  default  wbeditentity-FullishItems        2000.0
#
#      start_time     stop_time    time success_line statistics  group  note
# 0  1.743020e+09  1.743021e+09  1064.0         4008         {}    NaN   NaN
# 1  1.743021e+09  1.743021e+09   217.0         6014         {}    NaN   NaN
# 2  1.743022e+09  1.743022e+09    34.0         8020         {}    NaN   NaN
# 3  1.743022e+09  1.743022e+09    32.0        10026         {}    NaN   NaN
# 4  1.743022e+09  1.743022e+09    31.0        12032         {}    NaN   NaN

# %%
# Group by the various attribs, and count the occurrences
grouped_df = df.groupby(['instance', 'async', 'image', 'sql', 'setting', 'load', 'entity_count', 'group']).size().reset_index(name='count')
# Sort the grouped DataFrame by 'count' in descending order
grouped_df = grouped_df.sort_values(by='count', ascending=False)

# Display the first few rows of the sorted DataFrame
grouped_df
# Out:
#     instance  async                             image           sql  \
# 27       1.0   30.0        wikibase/wikibase:mw1.43.0  mariadb:11.7
# 25       1.0   30.0        wikibase/wikibase:mw1.43.0  mariadb:11.7
# 39       1.0   60.0        wikibase/wikibase:mw1.43.0  mariadb:11.7
# 23       1.0   30.0        wikibase/wikibase:mw1.43.0  mariadb:10.9
# 38       1.0   60.0        wikibase/wikibase:mw1.43.0  mariadb:11.7
# 41       1.0  100.0        wikibase/wikibase:mw1.43.0  mariadb:11.7
# 40       1.0  100.0        wikibase/wikibase:mw1.43.0  mariadb:11.7
# 24       1.0   30.0        wikibase/wikibase:mw1.43.0  mariadb:11.7
# 32       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11  mariadb:11.7
# 15       1.0   30.0  wikibase/wikibase:1.39.1-wmde.11  mariadb:11.7
# 34       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11  mariadb:11.7
# 30       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11  mariadb:11.7
# 29       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11  mariadb:11.7
# 19       1.0   30.0  wikibase/wikibase:1.41.1-wmde.20  mariadb:11.7
# 17       1.0   30.0  wikibase/wikibase:1.40.3-wmde.19  mariadb:11.7
# 0        1.0    1.0  wikibase/wikibase:1.39.1-wmde.11  mariadb:11.7
# 21       1.0   30.0        wikibase/wikibase:mw1.42.5  mariadb:11.7
# 13       1.0   10.0        wikibase/wikibase:mw1.43.0  mariadb:11.7
# 3        1.0    5.0  wikibase/wikibase:1.39.1-wmde.11  mariadb:11.7
# 5        1.0   10.0  wikibase/wikibase:1.39.1-wmde.11  mariadb:11.7
# 33       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11  mariadb:11.7
# 14       1.0   10.0        wikibase/wikibase:mw1.43.0  mariadb:11.7
# 7        1.0   10.0  wikibase/wikibase:1.40.3-wmde.19  mariadb:11.7
# 2        1.0    1.0        wikibase/wikibase:mw1.43.0  mariadb:11.7
# 4        1.0   10.0  wikibase/wikibase:1.39.1-wmde.11  mariadb:11.7
# 37       1.0   60.0        wikibase/wikibase:mw1.42.5  mariadb:11.7
# 36       1.0   60.0  wikibase/wikibase:1.41.1-wmde.20  mariadb:11.7
# 35       1.0   60.0  wikibase/wikibase:1.40.3-wmde.19  mariadb:11.7
# 6        1.0   10.0  wikibase/wikibase:1.40.3-wmde.19  mariadb:11.7
# 31       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11  mariadb:11.7
# 16       1.0   30.0  wikibase/wikibase:1.39.1-wmde.11  mariadb:11.7
# 28       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11  mariadb:11.7
# 9        1.0   10.0  wikibase/wikibase:1.41.1-wmde.20  mariadb:11.7
# 26       1.0   30.0        wikibase/wikibase:mw1.43.0  mariadb:11.7
# 10       1.0   10.0        wikibase/wikibase:mw1.42.5  mariadb:11.7
# 11       1.0   10.0        wikibase/wikibase:mw1.42.5  mariadb:11.7
# 12       1.0   10.0        wikibase/wikibase:mw1.43.0  mariadb:11.7
# 22       1.0   30.0        wikibase/wikibase:mw1.42.5  mariadb:11.7
# 1        1.0    1.0        wikibase/wikibase:mw1.43.0  mariadb:11.7
# 20       1.0   30.0  wikibase/wikibase:1.41.1-wmde.20  mariadb:11.7
# 18       1.0   30.0  wikibase/wikibase:1.40.3-wmde.19  mariadb:11.7
# 8        1.0   10.0  wikibase/wikibase:1.41.1-wmde.20  mariadb:11.7
#
#                     setting                       load  entity_count  group  \
# 27  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0    1.0
# 25        wbOwnIdConnection  wbeditentity-FullishItems        5000.0    1.0
# 39        wbOwnIdConnection  wbeditentity-FullishItems        5000.0    1.0
# 23        wbOwnIdConnection  wbeditentity-FullishItems        5000.0    1.0
# 38        wbOwnIdConnection          rest-FullishItems        5000.0    1.0
# 41        wbOwnIdConnection  wbeditentity-FullishItems        5000.0    1.0
# 40        wbOwnIdConnection          rest-FullishItems        5000.0    1.0
# 24        wbOwnIdConnection          rest-FullishItems        5000.0    1.0
# 32        wbOwnIdConnection  wbfastimport-FullishItems        5000.0   10.0
# 15        wbOwnIdConnection  wbeditentity-FullishItems        5000.0    1.0
# 34        wbOwnIdConnection  wbfastimport-FullishItems        5000.0   50.0
# 30        wbOwnIdConnection  wbfastimport-FullishItems        5000.0    2.0
# 29        wbOwnIdConnection  wbfastimport-FullishItems        5000.0    1.0
# 19        wbOwnIdConnection  wbeditentity-FullishItems        5000.0    1.0
# 17        wbOwnIdConnection  wbeditentity-FullishItems        5000.0    1.0
# 0         wbOwnIdConnection  wbfastimport-FullishItems        5000.0   50.0
# 21        wbOwnIdConnection  wbeditentity-FullishItems        5000.0    1.0
# 13        wbOwnIdConnection  wbeditentity-FullishItems        5000.0    1.0
# 3         wbOwnIdConnection  wbfastimport-FullishItems        5000.0   50.0
# 5         wbOwnIdConnection  wbfastimport-FullishItems        5000.0   50.0
# 33        wbOwnIdConnection  wbfastimport-FullishItems        5000.0   25.0
# 14        wbOwnIdConnection  wbfastimport-FullishItems        5000.0   50.0
# 7         wbOwnIdConnection  wbfastimport-FullishItems        5000.0   50.0
# 2         wbOwnIdConnection  wbeditentity-FullishItems        5000.0    1.0
# 4         wbOwnIdConnection  wbeditentity-FullishItems        5000.0    1.0
# 37        wbOwnIdConnection  wbeditentity-FullishItems        5000.0    1.0
# 36        wbOwnIdConnection  wbeditentity-FullishItems        5000.0    1.0
# 35        wbOwnIdConnection  wbeditentity-FullishItems        5000.0    1.0
# 6         wbOwnIdConnection  wbeditentity-FullishItems        5000.0    1.0
# 31        wbOwnIdConnection  wbfastimport-FullishItems        5000.0    5.0
# 16        wbOwnIdConnection  wbfastimport-FullishItems        5000.0    1.0
# 28        wbOwnIdConnection  wbeditentity-FullishItems        5000.0    1.0
# 9         wbOwnIdConnection  wbfastimport-FullishItems        5000.0   50.0
# 26        wbOwnIdConnection  wbfastimport-FullishItems        5000.0    1.0
# 10        wbOwnIdConnection  wbeditentity-FullishItems        5000.0    1.0
# 11        wbOwnIdConnection  wbfastimport-FullishItems        5000.0   50.0
# 12        wbOwnIdConnection          rest-FullishItems        5000.0    1.0
# 22        wbOwnIdConnection  wbfastimport-FullishItems        5000.0    1.0
# 1         wbOwnIdConnection          rest-FullishItems        5000.0    1.0
# 20        wbOwnIdConnection  wbfastimport-FullishItems        5000.0    1.0
# 18        wbOwnIdConnection  wbfastimport-FullishItems        5000.0    1.0
# 8         wbOwnIdConnection  wbeditentity-FullishItems        5000.0    1.0
#
#     count
# 27     25
# 25     25
# 39     10
# 23     10
# 38      9
# 41      7
# 40      7
# 24      7
# 32      4
# 15      3
# 34      3
# 30      3
# 29      3
# 19      3
# 17      3
# 0       3
# 21      3
# 13      2
# 3       2
# 5       2
# 33      2
# 14      2
# 7       1
# 2       1
# 4       1
# 37      1
# 36      1
# 35      1
# 6       1
# 31      1
# 16      1
# 28      1
# 9       1
# 26      1
# 10      1
# 11      1
# 12      1
# 22      1
# 1       1
# 20      1
# 18      1
# 8       1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter the original DataFrame to match the db_compare conditions
filtered_df = df[
    ((df['setting'] == 'lightweight') | (df['setting'] == 'default')) &
    (df['load'] == 'wbeditentity-FullishItems') &
    (df['image'] == 'wikibase/wikibase:1.39.1-wmde.11') &
    (df['sql'] == 'mariadb:10.9') &
    # (df['instance'] == 1) &
    (df['entity_count'] == 2000) &
    (df['async'] == 60)
]

print(filtered_df)
print(f"Number of rows: {len(filtered_df)}")

# Output in a table a summary of the filtered df, with min, max, and mean time
summary_df = filtered_df.groupby('setting')['time'].agg(['min', 'max', 'mean']).reset_index()
# Display the summary DataFrame
print(summary_df)
# Out:
#        runtime  instance  async                             image  \
# 2   1743021474       2.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 3   1743021639       2.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 4   1743021790       2.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 5   1743021880       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 6   1743022322       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 7   1743025222       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 8   1743025509       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 10  1743025750       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 11  1743025996       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 12  1743026142       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 13  1743026571       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11
#
#              sql      setting                       load  entity_count  \
# 2   mariadb:10.9      default  wbeditentity-FullishItems        2000.0
# 3   mariadb:10.9      default  wbeditentity-FullishItems        2000.0
# 4   mariadb:10.9      default  wbeditentity-FullishItems        2000.0
# 5   mariadb:10.9      default  wbeditentity-FullishItems        2000.0
# 6   mariadb:10.9      default  wbeditentity-FullishItems        2000.0
# 7   mariadb:10.9      default  wbeditentity-FullishItems        2000.0
# 8   mariadb:10.9      default  wbeditentity-FullishItems        2000.0
# 10  mariadb:10.9  lightweight  wbeditentity-FullishItems        2000.0
# 11  mariadb:10.9  lightweight  wbeditentity-FullishItems        2000.0
# 12  mariadb:10.9  lightweight  wbeditentity-FullishItems        2000.0
# 13  mariadb:10.9  lightweight  wbeditentity-FullishItems        2000.0
#
#       start_time     stop_time  time success_line statistics  group  note
# 2   1.743022e+09  1.743022e+09  34.0         8020         {}    NaN   NaN
# 3   1.743022e+09  1.743022e+09  32.0        10026         {}    NaN   NaN
# 4   1.743022e+09  1.743022e+09  31.0        12032         {}    NaN   NaN
# 5   1.743022e+09  1.743022e+09  33.0        14038         {}    NaN   NaN
# 6   1.743022e+09  1.743022e+09  29.0        22062         {}    NaN   NaN
# 7   1.743025e+09  1.743025e+09  29.0      success         {}    NaN   NaN
# 8   1.743026e+09  1.743026e+09  28.0      success         {}    NaN   NaN
# 10  1.743026e+09  1.743026e+09  16.0      success         {}    NaN   NaN
# 11  1.743026e+09  1.743026e+09  15.0      success         {}    NaN   NaN
# 12  1.743026e+09  1.743026e+09  15.0      success         {}    NaN   NaN
# 13  1.743027e+09  1.743027e+09  17.0      success         {}    NaN   NaN
# Number of rows: 11
#        setting   min   max       mean
# 0      default  28.0  34.0  30.857143
# 1  lightweight  15.0  17.0  15.750000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter the original DataFrame to match the db_compare conditions
filtered_df = df[
    (df['setting'] == 'lightweight') &
    (df['load'] == 'wbeditentity-FullishItems') &
    (df['image'] == 'wikibase/wikibase:1.39.1-wmde.11') &
    (df['instance'] == 1) &
    (df['entity_count'] == 2000) &
    (df['async'] == 60)
]

print(filtered_df)
print(f"Number of rows: {len(filtered_df)}")

# Output in a table a summary of the filtered df, with min, max, and mean time
summary_df = filtered_df.groupby('sql')['time'].agg(['min', 'max', 'mean']).reset_index()
# Display the summary DataFrame
print(summary_df)
# Out:
#        runtime  instance  async                             image  \
# 10  1743025750       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 11  1743025996       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 12  1743026142       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 13  1743026571       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 14  1743028132       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 15  1743028206       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 16  1743028356       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 17  1743028437       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11
# 18  1743028520       1.0   60.0  wikibase/wikibase:1.39.1-wmde.11
#
#              sql      setting                       load  entity_count  \
# 10  mariadb:10.9  lightweight  wbeditentity-FullishItems        2000.0
# 11  mariadb:10.9  lightweight  wbeditentity-FullishItems        2000.0
# 12  mariadb:10.9  lightweight  wbeditentity-FullishItems        2000.0
# 13  mariadb:10.9  lightweight  wbeditentity-FullishItems        2000.0
# 14  mariadb:11.7  lightweight  wbeditentity-FullishItems        2000.0
# 15  mariadb:11.7  lightweight  wbeditentity-FullishItems        2000.0
# 16  mariadb:11.7  lightweight  wbeditentity-FullishItems        2000.0
# 17  mariadb:11.7  lightweight  wbeditentity-FullishItems        2000.0
# 18  mariadb:11.7  lightweight  wbeditentity-FullishItems        2000.0
#
#       start_time     stop_time  time success_line statistics  group  note
# 10  1.743026e+09  1.743026e+09  16.0      success         {}    NaN   NaN
# 11  1.743026e+09  1.743026e+09  15.0      success         {}    NaN   NaN
# 12  1.743026e+09  1.743026e+09  15.0      success         {}    NaN   NaN
# 13  1.743027e+09  1.743027e+09  17.0      success         {}    NaN   NaN
# 14  1.743028e+09  1.743028e+09  14.0         2006         {}    NaN   NaN
# 15  1.743028e+09  1.743028e+09  14.0         2006         {}    NaN   NaN
# 16  1.743028e+09  1.743028e+09  17.0         2006         {}    NaN   NaN
# 17  1.743028e+09  1.743028e+09  14.0         2006         {}    NaN   NaN
# 18  1.743029e+09  1.743029e+09  17.0         2006         {}    NaN   NaN
# Number of rows: 9
#             sql   min   max   mean
# 0  mariadb:10.9  15.0  17.0  15.75
# 1  mariadb:11.7  14.0  17.0  15.20

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter the original DataFrame to match the db_compare conditions
filtered_df = df[
    (df['setting'] == 'wbOwnIdConnection') &
    (df['image'] == 'wikibase/wikibase:mw1.43.0') &
    (df['load'] == 'wbeditentity-FullishItems') &
    (df['async'] == 30)
]

print(filtered_df)
print(f"Number of rows: {len(filtered_df)}")

# Output in a table a summary of the filtered df, with min, max, and mean time
summary_df = filtered_df.groupby('sql')['time'].agg(['min', 'max', 'mean']).reset_index()
# Display the summary DataFrame
print(summary_df)
# Out:
#         runtime  instance  async                       image           sql  \
# 73   1743166021       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 79   1743166671       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 85   1743167673       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 91   1743168284       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 98   1743169654       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 104  1743170218       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 110  1743170784       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 125  1743172782       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 132  1743173384       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 147  1743175259       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 149  1743175746       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:10.9
# 150  1743175834       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 151  1743176049       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:10.9
# 152  1743176132       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 153  1743176219       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:10.9
# 154  1743176303       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 155  1743176389       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:10.9
# 156  1743176473       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 157  1743176557       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:10.9
# 158  1743176641       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 159  1743176724       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:10.9
# 160  1743176810       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 161  1743176893       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:10.9
# 162  1743176980       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 163  1743177063       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:10.9
# 164  1743177149       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 165  1743177232       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:10.9
# 166  1743177315       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 167  1743177401       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:10.9
# 168  1743177483       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
#
#                setting                       load  entity_count    start_time  \
# 73   wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743166e+09
# 79   wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743167e+09
# 85   wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743168e+09
# 91   wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743168e+09
# 98   wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743170e+09
# 104  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743170e+09
# 110  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743171e+09
# 125  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743173e+09
# 132  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743173e+09
# 147  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743175e+09
# 149  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743176e+09
# 150  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743176e+09
# 151  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743176e+09
# 152  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743176e+09
# 153  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743176e+09
# 154  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743176e+09
# 155  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743176e+09
# 156  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743176e+09
# 157  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743177e+09
# 158  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743177e+09
# 159  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743177e+09
# 160  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743177e+09
# 161  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743177e+09
# 162  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743177e+09
# 163  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743177e+09
# 164  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743177e+09
# 165  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743177e+09
# 166  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743177e+09
# 167  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743177e+09
# 168  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743178e+09
#
#         stop_time  time success_line statistics  group  note
# 73   1.743166e+09  62.0         5006         {}    1.0   NaN
# 79   1.743167e+09  65.0         5006         {}    1.0   NaN
# 85   1.743168e+09  64.0         5006         {}    1.0   NaN
# 91   1.743168e+09  62.0         5006         {}    1.0   NaN
# 98   1.743170e+09  51.0         5006         {}    1.0   NaN
# 104  1.743170e+09  54.0         5006         {}    1.0   NaN
# 110  1.743171e+09  53.0         5006         {}    1.0   NaN
# 125  1.743173e+09  50.0         5006         {}    1.0   NaN
# 132  1.743173e+09  47.0         5006         {}    1.0   NaN
# 147  1.743175e+09  45.0         5006         {}    1.0   NaN
# 149  1.743176e+09  48.0         5006         {}    1.0   NaN
# 150  1.743176e+09  47.0         5006         {}    1.0   NaN
# 151  1.743176e+09  45.0         5006         {}    1.0   NaN
# 152  1.743176e+09  46.0         5006         {}    1.0   NaN
# 153  1.743176e+09  45.0         5006         {}    1.0   NaN
# 154  1.743176e+09  45.0         5006         {}    1.0   NaN
# 155  1.743176e+09  48.0         5006         {}    1.0   NaN
# 156  1.743177e+09  44.0         5006         {}    1.0   NaN
# 157  1.743177e+09  47.0         5006         {}    1.0   NaN
# 158  1.743177e+09  44.0         5006         {}    1.0   NaN
# 159  1.743177e+09  45.0         5006         {}    1.0   NaN
# 160  1.743177e+09  45.0         5006         {}    1.0   NaN
# 161  1.743177e+09  45.0         5006         {}    1.0   NaN
# 162  1.743177e+09  47.0         5006         {}    1.0   NaN
# 163  1.743177e+09  45.0         5006         {}    1.0   NaN
# 164  1.743177e+09  47.0         5006         {}    1.0   NaN
# 165  1.743177e+09  45.0         5006         {}    1.0   NaN
# 166  1.743177e+09  44.0         5006         {}    1.0   NaN
# 167  1.743177e+09  47.0         5006         {}    1.0   NaN
# 168  1.743178e+09  46.0         5006         {}    1.0   NaN
# Number of rows: 30
#             sql   min   max  mean
# 0  mariadb:10.9  45.0  48.0  46.0
# 1  mariadb:11.7  44.0  65.0  50.4

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter the original DataFrame to match the db_compare conditions
filtered_df = df[
    (df['sql'] == 'mariadb:11.7') &
    (df['setting'] == 'wbOwnIdConnection') &
    (df['image'] == 'wikibase/wikibase:mw1.43.0') &
    (df['load'] != 'wbfastimport-FullishItems') &
    (df['async'] == 30)
]

print(filtered_df)
# How many rows
print(f"Number of rows: {len(filtered_df)}")

# Output in a table a summary of the filtered df, with min, max, and mean time
summary_df = filtered_df.groupby('load')['time'].agg(['min', 'max', 'mean']).reset_index()
# Display the summary DataFrame
print(summary_df)
# Out:
#         runtime  instance  async                       image           sql  \
# 73   1743166021       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 74   1743166133       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 79   1743166671       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 80   1743166776       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 85   1743167673       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 86   1743167777       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 91   1743168284       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 92   1743168386       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 98   1743169654       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 99   1743169747       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 104  1743170218       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 105  1743170311       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 110  1743170784       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 111  1743170874       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 125  1743172782       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 132  1743173384       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 147  1743175259       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 150  1743175834       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 152  1743176132       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 154  1743176303       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 156  1743176473       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 158  1743176641       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 160  1743176810       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 162  1743176980       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 164  1743177149       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 166  1743177315       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 168  1743177483       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
#
#                setting                       load  entity_count    start_time  \
# 73   wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743166e+09
# 74   wbOwnIdConnection          rest-FullishItems        5000.0  1.743166e+09
# 79   wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743167e+09
# 80   wbOwnIdConnection          rest-FullishItems        5000.0  1.743167e+09
# 85   wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743168e+09
# 86   wbOwnIdConnection          rest-FullishItems        5000.0  1.743168e+09
# 91   wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743168e+09
# 92   wbOwnIdConnection          rest-FullishItems        5000.0  1.743168e+09
# 98   wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743170e+09
# 99   wbOwnIdConnection          rest-FullishItems        5000.0  1.743170e+09
# 104  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743170e+09
# 105  wbOwnIdConnection          rest-FullishItems        5000.0  1.743170e+09
# 110  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743171e+09
# 111  wbOwnIdConnection          rest-FullishItems        5000.0  1.743171e+09
# 125  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743173e+09
# 132  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743173e+09
# 147  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743175e+09
# 150  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743176e+09
# 152  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743176e+09
# 154  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743176e+09
# 156  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743176e+09
# 158  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743177e+09
# 160  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743177e+09
# 162  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743177e+09
# 164  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743177e+09
# 166  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743177e+09
# 168  wbOwnIdConnection  wbeditentity-FullishItems        5000.0  1.743178e+09
#
#         stop_time  time success_line statistics  group  note
# 73   1.743166e+09  62.0         5006         {}    1.0   NaN
# 74   1.743166e+09  81.0         5006         {}    1.0   NaN
# 79   1.743167e+09  65.0         5006         {}    1.0   NaN
# 80   1.743167e+09  78.0         5006         {}    1.0   NaN
# 85   1.743168e+09  64.0         5006         {}    1.0   NaN
# 86   1.743168e+09  78.0         5006         {}    1.0   NaN
# 91   1.743168e+09  62.0         5006         {}    1.0   NaN
# 92   1.743168e+09  77.0         5006         {}    1.0   NaN
# 98   1.743170e+09  51.0         5006         {}    1.0   NaN
# 99   1.743170e+09  57.0         5006         {}    1.0   NaN
# 104  1.743170e+09  54.0         5006         {}    1.0   NaN
# 105  1.743170e+09  58.0         5006         {}    1.0   NaN
# 110  1.743171e+09  53.0         5006         {}    1.0   NaN
# 111  1.743171e+09  57.0         5006         {}    1.0   NaN
# 125  1.743173e+09  50.0         5006         {}    1.0   NaN
# 132  1.743173e+09  47.0         5006         {}    1.0   NaN
# 147  1.743175e+09  45.0         5006         {}    1.0   NaN
# 150  1.743176e+09  47.0         5006         {}    1.0   NaN
# 152  1.743176e+09  46.0         5006         {}    1.0   NaN
# 154  1.743176e+09  45.0         5006         {}    1.0   NaN
# 156  1.743177e+09  44.0         5006         {}    1.0   NaN
# 158  1.743177e+09  44.0         5006         {}    1.0   NaN
# 160  1.743177e+09  45.0         5006         {}    1.0   NaN
# 162  1.743177e+09  47.0         5006         {}    1.0   NaN
# 164  1.743177e+09  47.0         5006         {}    1.0   NaN
# 166  1.743177e+09  44.0         5006         {}    1.0   NaN
# 168  1.743178e+09  46.0         5006         {}    1.0   NaN
# Number of rows: 27
#                         load   min   max       mean
# 0          rest-FullishItems  57.0  81.0  69.428571
# 1  wbeditentity-FullishItems  44.0  65.0  50.400000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter the original DataFrame to match the db_compare conditions
filtered_df = df[
    (df['sql'] == 'mariadb:11.7') &
    ((df['setting'] == 'wbOwnIdConnectionUpsert') | (df['setting'] == 'wbOwnIdConnection')) &
    (df['image'] == 'wikibase/wikibase:mw1.43.0') &
    (df['load'] == 'wbeditentity-FullishItems') &
    (df['async'] == 30) &
    (df['instance'] == 1) &
    (df['entity_count'] == 5000)
]

print(filtered_df)
# How many rows
print(f"Number of rows: {len(filtered_df)}")

# Output in a table a summary of the filtered df, with min, max, and mean time
summary_df = filtered_df.groupby('setting')['time'].agg(['min', 'max', 'mean']).reset_index()
# Add a column for the count of items in each group
summary_df['count'] = filtered_df.groupby('setting')['time'].size().values
# Display the summary DataFrame
print(summary_df)
# Out:
#         runtime  instance  async                       image           sql  \
# 73   1743166021       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 79   1743166671       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 85   1743167673       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 91   1743168284       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 98   1743169654       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 104  1743170218       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 110  1743170784       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 125  1743172782       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 132  1743173384       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 147  1743175259       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 150  1743175834       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 152  1743176132       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 154  1743176303       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 156  1743176473       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 158  1743176641       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 160  1743176810       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 162  1743176980       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 164  1743177149       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 166  1743177315       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 168  1743177483       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 169  1743179965       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 170  1743180063       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 171  1743180146       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 172  1743180232       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 173  1743180318       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 174  1743180405       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 175  1743180492       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 176  1743180580       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 177  1743180669       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 178  1743180753       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 179  1743181178       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 180  1743181262       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 181  1743181350       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 182  1743181436       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 183  1743181524       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 184  1743181843       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 185  1743181932       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 186  1743182016       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 187  1743182102       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 188  1743182186       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 189  1743182270       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 190  1743182356       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 191  1743182438       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 192  1743182519       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 193  1743182600       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 194  1743182681       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 195  1743182762       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 196  1743182843       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 197  1743182924       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
# 198  1743183005       1.0   30.0  wikibase/wikibase:mw1.43.0  mariadb:11.7
#
#                      setting                       load  entity_count  \
# 73         wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 79         wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 85         wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 91         wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 98         wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 104        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 110        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 125        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 132        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 147        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 150        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 152        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 154        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 156        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 158        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 160        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 162        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 164        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 166        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 168        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 169  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 170  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 171  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 172  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 173  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 174  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 175  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 176  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 177  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 178  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 179        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 180        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 181        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 182        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 183        wbOwnIdConnection  wbeditentity-FullishItems        5000.0
# 184  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 185  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 186  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 187  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 188  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 189  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 190  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 191  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 192  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 193  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 194  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 195  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 196  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 197  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
# 198  wbOwnIdConnectionUpsert  wbeditentity-FullishItems        5000.0
#
#        start_time     stop_time  time success_line statistics  group  note
# 73   1.743166e+09  1.743166e+09  62.0         5006         {}    1.0   NaN
# 79   1.743167e+09  1.743167e+09  65.0         5006         {}    1.0   NaN
# 85   1.743168e+09  1.743168e+09  64.0         5006         {}    1.0   NaN
# 91   1.743168e+09  1.743168e+09  62.0         5006         {}    1.0   NaN
# 98   1.743170e+09  1.743170e+09  51.0         5006         {}    1.0   NaN
# 104  1.743170e+09  1.743170e+09  54.0         5006         {}    1.0   NaN
# 110  1.743171e+09  1.743171e+09  53.0         5006         {}    1.0   NaN
# 125  1.743173e+09  1.743173e+09  50.0         5006         {}    1.0   NaN
# 132  1.743173e+09  1.743173e+09  47.0         5006         {}    1.0   NaN
# 147  1.743175e+09  1.743175e+09  45.0         5006         {}    1.0   NaN
# 150  1.743176e+09  1.743176e+09  47.0         5006         {}    1.0   NaN
# 152  1.743176e+09  1.743176e+09  46.0         5006         {}    1.0   NaN
# 154  1.743176e+09  1.743176e+09  45.0         5006         {}    1.0   NaN
# 156  1.743176e+09  1.743177e+09  44.0         5006         {}    1.0   NaN
# 158  1.743177e+09  1.743177e+09  44.0         5006         {}    1.0   NaN
# 160  1.743177e+09  1.743177e+09  45.0         5006         {}    1.0   NaN
# 162  1.743177e+09  1.743177e+09  47.0         5006         {}    1.0   NaN
# 164  1.743177e+09  1.743177e+09  47.0         5006         {}    1.0   NaN
# 166  1.743177e+09  1.743177e+09  44.0         5006         {}    1.0   NaN
# 168  1.743178e+09  1.743178e+09  46.0         5006         {}    1.0   NaN
# 169  1.743180e+09  1.743180e+09  45.0         5006         {}    1.0   NaN
# 170  1.743180e+09  1.743180e+09  46.0         5006         {}    1.0   NaN
# 171  1.743180e+09  1.743180e+09  45.0         5006         {}    1.0   NaN
# 172  1.743180e+09  1.743180e+09  49.0         5006         {}    1.0   NaN
# 173  1.743180e+09  1.743180e+09  47.0         5006         {}    1.0   NaN
# 174  1.743180e+09  1.743180e+09  48.0         5006         {}    1.0   NaN
# 175  1.743181e+09  1.743181e+09  50.0         5006         {}    1.0   NaN
# 176  1.743181e+09  1.743181e+09  49.0         5006         {}    1.0   NaN
# 177  1.743181e+09  1.743181e+09  49.0         5006         {}    1.0   NaN
# 178  1.743181e+09  1.743181e+09  44.0         5006         {}    1.0   NaN
# 179  1.743181e+09  1.743181e+09  48.0         5006         {}    1.0   NaN
# 180  1.743181e+09  1.743181e+09  48.0         5006         {}    1.0   NaN
# 181  1.743181e+09  1.743181e+09  48.0         5006         {}    1.0   NaN
# 182  1.743181e+09  1.743182e+09  47.0         5006         {}    1.0   NaN
# 183  1.743182e+09  1.743182e+09  50.0         5006         {}    1.0   NaN
# 184  1.743182e+09  1.743182e+09  52.0         5006         {}    1.0   NaN
# 185  1.743182e+09  1.743182e+09  48.0         5006         {}    1.0   NaN
# 186  1.743182e+09  1.743182e+09  49.0         5006         {}    1.0   NaN
# 187  1.743182e+09  1.743182e+09  47.0         5006         {}    1.0   NaN
# 188  1.743182e+09  1.743182e+09  47.0         5006         {}    1.0   NaN
# 189  1.743182e+09  1.743182e+09  49.0         5006         {}    1.0   NaN
# 190  1.743182e+09  1.743182e+09  46.0         5006         {}    1.0   NaN
# 191  1.743182e+09  1.743183e+09  45.0         5006         {}    1.0   NaN
# 192  1.743183e+09  1.743183e+09  45.0         5006         {}    1.0   NaN
# 193  1.743183e+09  1.743183e+09  44.0         5006         {}    1.0   NaN
# 194  1.743183e+09  1.743183e+09  45.0         5006         {}    1.0   NaN
# 195  1.743183e+09  1.743183e+09  45.0         5006         {}    1.0   NaN
# 196  1.743183e+09  1.743183e+09  45.0         5006         {}    1.0   NaN
# 197  1.743183e+09  1.743183e+09  44.0         5006         {}    1.0   NaN
# 198  1.743183e+09  1.743183e+09  44.0         5006         {}    1.0   NaN
# Number of rows: 50
#                    setting   min   max   mean  count
# 0        wbOwnIdConnection  44.0  65.0  49.96     25
# 1  wbOwnIdConnectionUpsert  44.0  52.0  46.68     25

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter the original DataFrame to match the db_compare conditions
filtered_df = df[
    (df['sql'] == 'mariadb:11.7') &
    ((df['setting'] == 'wbfastimport-FullishItems')) &
    (df['image'] == 'wikibase/wikibase:mw1.43.0') &
    (df['load'] == 'wbeditentity-FullishItems') &
    (df['async'] == 30) &
    (df['instance'] == 1) &
    (df['entity_count'] == 5000)
]

print(filtered_df)
# How many rows
print(f"Number of rows: {len(filtered_df)}")

# Output in a table a summary of the filtered df, with min, max, and mean time
summary_df = filtered_df.groupby('setting')['time'].agg(['min', 'max', 'mean']).reset_index()
# Add a column for the count of items in each group
summary_df['count'] = filtered_df.groupby('setting')['time'].size().values
# Display the summary DataFrame
print(summary_df)
